# %% [markdown]
# ### Introduction to pandas!
#
# What we will learn in this notebook:
# - how to open and read in a csv spreadsheet
# - how to look at the data we have
# - how to select columns
# - how to do some math with them

# %% [markdown]
# First we need to import pandas as a library. We import the library and then tell Python to refer to it as `pd`:

# %%
import pandas as pd
import matplotlib.pyplot as plot
import numpy 
import seaborn 
import datetime

# %% [markdown]
# ### Reading spreadsheets
#
# This is how you read a spreadsheet and assign it to a variable:

# %%
# Bring in all my spreadsheets 
voters1 = pd.read_csv('SC-List-Asof-10-15-18-Pt1.csv')
voters2 = pd.read_csv('SC-List-Asof-10-15-18-Pt2.csv')
voters3 = pd.read_csv('SC-List-Asof-10-15-18-Pt3.csv')
# Out:
# /Users/erinmansfield/.local/share/virtualenvs/NICAR19-OcyWicxO/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (9,13,21,38,40,42,47,49,62,91,92,100,101,140,142,143,154,155,181,182,187,188,199,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/erinmansfield/.local/share/virtualenvs/NICAR19-OcyWicxO/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (9,10,13,21,37,38,49,62,91,92,100,101,140,154,155,181,182,187,188,199,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/erinmansfield/.local/share/virtualenvs/NICAR19-OcyWicxO/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (9,13,21,49,62,100,101,140,181,182,199,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Looking at your data
#
# To look at the data you just read into Python, you can just run a cell with the name of the variable:

# %%
voters1.head(5)
# Out:
#     SOS_VoterID  idnumber voter_status  party_code lastname  firstname  \
# 0  2.140230e+09  80139849            S         NaN    ADAMS  DOMINIQUE
# 1  1.128803e+09       287            A         NaN    ADAMS     WILLIE
# 2  2.140351e+09  80140000            A         NaN  AGUILAR      EDGAR
# 3  1.129249e+09    242762            A         NaN  AGUILAR      MARIA
# 4  1.182291e+09  80077967            A         NaN  ALARCON     JAZMIN
#
#   middlename namesuffix  streetnumber streetbuilding  ... party_code40  \
# 0     ALEXIS        NaN          3400            NaN  ...          NaN
# 1        RAY        NaN          2801            NaN  ...          NaN
# 2       IVAN        NaN          1121            NaN  ...          NaN
# 3       CRUZ        NaN          1121            NaN  ...          NaN
# 4        NaN        NaN           269            NaN  ...          NaN
#
#   registration_date party_affiliation_date last_activity_date precinct_group  \
# 0          10/10/17               10/10/17             2/8/18            NaN
# 1            1/4/76                    NaN            1/28/15            NaN
# 2          10/13/17               10/13/17            7/27/18            NaN
# 3           3/22/01                    NaN            1/28/15            NaN
# 4           1/24/12                    NaN            10/4/17            NaN
#
#   phone_number ID_Compliant  Absentee_Category  Absentee_Category_Date  \
# 0          NaN            Y                NaN                     NaN
# 1          NaN            Y                NaN                     NaN
# 2          NaN            Y                NaN                     NaN
# 3          NaN            Y                NaN                     NaN
# 4          NaN            Y                NaN                     NaN
#
#   Ethnicity
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 211 columns]

# %%
voters1.tail(5)
# Out:
#         SOS_VoterID  idnumber voter_status  party_code     lastname firstname  \
# 89191  2.148931e+09  80149269            A         NaN      BURGESS    ISIAHA
# 89192  1.129061e+09    146819            A         NaN      BURKHAM    MARLON
# 89193  1.177610e+09  80073294            A         NaN  BURKS-JONES    BESSIE
# 89194  1.128479e+09    237499            A         NaN     BURNETTE    SHERRY
# 89195  1.129018e+09    150343            A         NaN        BURNS     FAIRY
#
#       middlename namesuffix  streetnumber streetbuilding  ... party_code40  \
# 89191     JAVONE        NaN         12993            NaN  ...          NaN
# 89192    RANDALL        NaN         15075            NaN  ...          NaN
# 89193        LEE        NaN         13652            NaN  ...          NaN
# 89194      KOTON        NaN          7259            NaN  ...          NaN
# 89195       WARD        NaN         13065            NaN  ...          NaN
#
#       registration_date party_affiliation_date last_activity_date  \
# 89191           9/27/18                9/27/18            9/28/18
# 89192           8/17/07                    NaN            3/10/15
# 89193           3/30/11                    NaN            8/27/14
# 89194           10/6/00                    NaN            1/28/15
# 89195           8/24/88                    NaN           11/10/14
#
#       precinct_group phone_number ID_Compliant  Absentee_Category  \
# 89191            NaN          NaN            Y                NaN
# 89192            NaN          NaN            Y                NaN
# 89193            NaN          NaN            Y                NaN
# 89194            NaN          NaN            Y                NaN
# 89195            NaN          NaN            Y                NaN
#
#        Absentee_Category_Date Ethnicity
# 89191                     NaN       NaN
# 89192                     NaN       NaN
# 89193                     NaN       NaN
# 89194                     NaN       NaN
# 89195                     NaN       NaN
#
# [5 rows x 211 columns]

# %%
# Find out the length of one of the tables 
len(voters2)
# Out:
# 18712

# %%
# The pandas equivalent of Excel's transpose 
voters1.T
# Out:
#                                0                1            2      \
# SOS_VoterID              2.14023e+09       1.1288e+09  2.14035e+09
# idnumber                    80139849              287     80140000
# voter_status                       S                A            A
# party_code                       NaN              NaN          NaN
# lastname                       ADAMS            ADAMS      AGUILAR
# firstname                  DOMINIQUE           WILLIE        EDGAR
# middlename                    ALEXIS              RAY         IVAN
# namesuffix                       NaN              NaN          NaN
# streetnumber                    3400             2801         1121
# streetbuilding                   NaN              NaN          NaN
# streetpredir                     NaN              NaN          NaN
# streetname              NNE LOOP 323  COUNTY ROAD 376   MONTGOMERY
# streettype                       NaN              NaN         GDNS
# streetpostdir                    NaN              NaN          NaN
# unit_type                       TRLR              NaN          NaN
# unit                              28              NaN          NaN
# city                           TYLER            TYLER        TYLER
# zip                            75708            75708        75708
# zip4                             NaN              NaN          NaN
# mail1                            NaN              NaN          NaN
# mail2                            NaN              NaN          NaN
# mail3                            NaN              NaN          NaN
# mailcity                         NaN              NaN          NaN
# mailstate                        NaN              NaN          NaN
# mailzip                          NaN              NaN          NaN
# mailzip4                         NaN              NaN          NaN
# sex                                F                M            M
# birthdate                    9/11/99           4/8/49      8/29/99
# eligible_date                11/7/17           2/3/76     11/12/17
# effective_date               11/7/17           1/1/12     11/12/17
# ...                              ...              ...          ...
# election_code34                  NaN              NaN          NaN
# vote_type34                      NaN              NaN          NaN
# party_code34                     NaN              NaN          NaN
# election_code35                  NaN              NaN          NaN
# vote_type35                      NaN              NaN          NaN
# party_code35                     NaN              NaN          NaN
# election_code36                  NaN              NaN          NaN
# vote_type36                      NaN              NaN          NaN
# party_code36                     NaN              NaN          NaN
# election_code37                  NaN              NaN          NaN
# vote_type37                      NaN              NaN          NaN
# party_code37                     NaN              NaN          NaN
# election_code38                  NaN              NaN          NaN
# vote_type38                      NaN              NaN          NaN
# party_code38                     NaN              NaN          NaN
# election_code39                  NaN              NaN          NaN
# vote_type39                      NaN              NaN          NaN
# party_code39                     NaN              NaN          NaN
# election_code40                  NaN              NaN          NaN
# vote_type40                      NaN              NaN          NaN
# party_code40                     NaN              NaN          NaN
# registration_date           10/10/17           1/4/76     10/13/17
# party_affiliation_date      10/10/17              NaN     10/13/17
# last_activity_date            2/8/18          1/28/15      7/27/18
# precinct_group                   NaN              NaN          NaN
# phone_number                     NaN              NaN          NaN
# ID_Compliant                       Y                Y            Y
# Absentee_Category                NaN              NaN          NaN
# Absentee_Category_Date           NaN              NaN          NaN
# Ethnicity                        NaN              NaN          NaN
#
#                                        3            4             5      \
# SOS_VoterID                      1.12925e+09  1.18229e+09   1.14622e+09
# idnumber                              242762     80077967        301628
# voter_status                               A            A             A
# party_code                               NaN          NaN           NaN
# lastname                             AGUILAR      ALARCON         ALLEN
# firstname                              MARIA       JAZMIN         SCOTT
# middlename                              CRUZ          NaN             W
# namesuffix                               NaN          NaN           NaN
# streetnumber                            1121          269          5075
# streetbuilding                           NaN          NaN           NaN
# streetpredir                             NaN            W           NaN
# streetname                        MONTGOMERY        DIXIE         FM 14
# streettype                              GDNS           LN           NaN
# streetpostdir                            NaN          NaN           NaN
# unit_type                                NaN          NaN           NaN
# unit                                     NaN          NaN           NaN
# city                                   TYLER        TYLER         TYLER
# zip                                    75708        75706         75706
# zip4                                     NaN          NaN           NaN
# mail1                   1121 MONTGOMERY GDNS          NaN  P O BOX 4995
# mail2                                    NaN          NaN           NaN
# mail3                                    NaN          NaN           NaN
# mailcity                               TYLER          NaN         TYLER
# mailstate                                 TX          NaN            TX
# mailzip                                75708          NaN         75712
# mailzip4                                 NaN          NaN           NaN
# sex                                        F            F             M
# birthdate                             5/3/74       8/2/82        6/9/62
# eligible_date                        4/21/01      2/23/12       10/7/07
# effective_date                        1/1/12      11/2/17        1/1/12
# ...                                      ...          ...           ...
# election_code34                          NaN          NaN           NaN
# vote_type34                              NaN          NaN           NaN
# party_code34                             NaN          NaN           NaN
# election_code35                          NaN          NaN           NaN
# vote_type35                              NaN          NaN           NaN
# party_code35                             NaN          NaN           NaN
# election_code36                          NaN          NaN           NaN
# vote_type36                              NaN          NaN           NaN
# party_code36                             NaN          NaN           NaN
# election_code37                          NaN          NaN           NaN
# vote_type37                              NaN          NaN           NaN
# party_code37                             NaN          NaN           NaN
# election_code38                          NaN          NaN           NaN
# vote_type38                              NaN          NaN           NaN
# party_code38                             NaN          NaN           NaN
# election_code39                          NaN          NaN           NaN
# vote_type39                              NaN          NaN           NaN
# party_code39                             NaN          NaN           NaN
# election_code40                          NaN          NaN           NaN
# vote_type40                              NaN          NaN           NaN
# party_code40                             NaN          NaN           NaN
# registration_date                    3/22/01      1/24/12        9/7/07
# party_affiliation_date                   NaN          NaN           NaN
# last_activity_date                   1/28/15      10/4/17       1/28/15
# precinct_group                           NaN          NaN           NaN
# phone_number                             NaN          NaN           NaN
# ID_Compliant                               Y            Y             Y
# Absentee_Category                        NaN          NaN           NaN
# Absentee_Category_Date                   NaN          NaN           NaN
# Ethnicity                                NaN          NaN           NaN
#
#                                6             7                   8      \
# SOS_VoterID              1.21249e+09    2.1444e+09         1.12855e+09
# idnumber                    80104869      80144417              192678
# voter_status                       A             A                   A
# party_code                       NaN           NaN                 NaN
# lastname                      ALONSO        ALONSO            ALVARADO
# firstname                  SILVESTRE       YASMELI                JUAN
# middlename                       NaN           NaN                   C
# namesuffix                        JR           NaN                 NaN
# streetnumber                    3400          3400                5375
# streetbuilding                   NaN           NaN                 NaN
# streetpredir                     NaN           NaN                 NaN
# streetname              NNE LOOP 323  NNE LOOP 323          HOLTZ CLAW
# streettype                       NaN           NaN                  DR
# streetpostdir                    NaN           NaN                 NaN
# unit_type                       TRLR          TRLR                 NaN
# unit                              86            86                 NaN
# city                           TYLER         TYLER               TYLER
# zip                            75708         75708               75706
# zip4                             NaN           NaN                 NaN
# mail1                            NaN           NaN  5375 HOLTZ CLAW DR
# mail2                            NaN           NaN                 NaN
# mail3                            NaN           NaN                 NaN
# mailcity                         NaN           NaN               TYLER
# mailstate                        NaN           NaN                  TX
# mailzip                          NaN           NaN               75706
# mailzip4                         NaN           NaN                 NaN
# sex                                M             F                   M
# birthdate                    7/28/96       6/23/99             6/25/74
# eligible_date                10/3/14       5/10/18             5/24/95
# effective_date               10/3/14       5/10/18             6/29/12
# ...                              ...           ...                 ...
# election_code34                  NaN           NaN                 NaN
# vote_type34                      NaN           NaN                 NaN
# party_code34                     NaN           NaN                 NaN
# election_code35                  NaN           NaN                 NaN
# vote_type35                      NaN           NaN                 NaN
# party_code35                     NaN           NaN                 NaN
# election_code36                  NaN           NaN                 NaN
# vote_type36                      NaN           NaN                 NaN
# party_code36                     NaN           NaN                 NaN
# election_code37                  NaN           NaN                 NaN
# vote_type37                      NaN           NaN                 NaN
# party_code37                     NaN           NaN                 NaN
# election_code38                  NaN           NaN                 NaN
# vote_type38                      NaN           NaN                 NaN
# party_code38                     NaN           NaN                 NaN
# election_code39                  NaN           NaN                 NaN
# vote_type39                      NaN           NaN                 NaN
# party_code39                     NaN           NaN                 NaN
# election_code40                  NaN           NaN                 NaN
# vote_type40                      NaN           NaN                 NaN
# party_code40                     NaN           NaN                 NaN
# registration_date             9/3/14       4/10/18             4/24/95
# party_affiliation_date        9/3/14       4/10/18                 NaN
# last_activity_date            9/5/14       4/11/18             1/28/15
# precinct_group                   NaN           NaN                 NaN
# phone_number                     NaN           NaN                 NaN
# ID_Compliant                       Y             Y                   Y
# Absentee_Category                NaN           NaN                 NaN
# Absentee_Category_Date           NaN           NaN                 NaN
# Ethnicity                        NaN           NaN                 NaN
#
#                               9      ...             89186             89187  \
# SOS_VoterID             1.21572e+09  ...       1.12834e+09       1.12857e+09
# idnumber                   80107559  ...             56531            222574
# voter_status                      S  ...                 A                 A
# party_code                      NaN  ...               NaN               NaN
# lastname                    ALVAREZ  ...             BUESS          BUHRKUHL
# firstname               ARISTOTELES  ...           FRANCES         CATHERINE
# middlename                      NaN  ...           LILLIAN           DEBORAH
# namesuffix                      NaN  ...               NaN               NaN
# streetnumber                    712  ...             13124             16218
# streetbuilding                  NaN  ...               NaN               NaN
# streetpredir                    NaN  ...               NaN               NaN
# streetname               MONTGOMERY  ...  COUNTY ROAD 1125  COUNTY ROAD 1113
# streettype                     GDNS  ...               NaN               NaN
# streetpostdir                   NaN  ...               NaN               NaN
# unit_type                       NaN  ...               NaN               NaN
# unit                            NaN  ...               NaN               NaN
# city                          TYLER  ...             TYLER             FLINT
# zip                           75708  ...             75709             75762
# zip4                            NaN  ...               NaN               NaN
# mail1                           NaN  ...     13124 CR 1125               NaN
# mail2                           NaN  ...               NaN               NaN
# mail3                           NaN  ...               NaN               NaN
# mailcity                        NaN  ...             TYLER               NaN
# mailstate                       NaN  ...                TX               NaN
# mailzip                         NaN  ...             75709               NaN
# mailzip4                        NaN  ...               NaN               NaN
# sex                               M  ...                 F                 F
# birthdate                   1/20/76  ...            5/3/25           9/29/57
# eligible_date              12/24/14  ...            3/9/76           5/23/99
# effective_date             12/24/14  ...            1/1/12            1/1/12
# ...                             ...  ...               ...               ...
# election_code34                 NaN  ...               NaN               NaN
# vote_type34                     NaN  ...               NaN               NaN
# party_code34                    NaN  ...               NaN               NaN
# election_code35                 NaN  ...               NaN               NaN
# vote_type35                     NaN  ...               NaN               NaN
# party_code35                    NaN  ...               NaN               NaN
# election_code36                 NaN  ...               NaN               NaN
# vote_type36                     NaN  ...               NaN               NaN
# party_code36                    NaN  ...               NaN               NaN
# election_code37                 NaN  ...               NaN               NaN
# vote_type37                     NaN  ...               NaN               NaN
# party_code37                    NaN  ...               NaN               NaN
# election_code38                 NaN  ...               NaN               NaN
# vote_type38                     NaN  ...               NaN               NaN
# party_code38                    NaN  ...               NaN               NaN
# election_code39                 NaN  ...               NaN               NaN
# vote_type39                     NaN  ...               NaN               NaN
# party_code39                    NaN  ...               NaN               NaN
# election_code40                 NaN  ...               NaN               NaN
# vote_type40                     NaN  ...               NaN               NaN
# party_code40                    NaN  ...               NaN               NaN
# registration_date          11/24/14  ...            2/8/76           4/23/99
# party_affiliation_date     11/24/14  ...               NaN               NaN
# last_activity_date          6/11/18  ...           3/10/15          11/10/14
# precinct_group                  NaN  ...               NaN               NaN
# phone_number                    NaN  ...               NaN               NaN
# ID_Compliant                      Y  ...                 Y                 Y
# Absentee_Category               NaN  ...               NaN               NaN
# Absentee_Category_Date          NaN  ...               NaN               NaN
# Ethnicity                       NaN  ...               NaN               NaN
#
#                                    89188             89189             89190  \
# SOS_VoterID                  1.12857e+09        2.1362e+09       1.12891e+09
# idnumber                          222576          80135295              6332
# voter_status                           A                 A                 A
# party_code                           NaN               NaN               NaN
# lastname                        BUHRKUHL             BUNTZ             BURCH
# firstname                          DAVID            JEREMY             LAFON
# middlename                        ROSSER           JACKSON              HELM
# namesuffix                           NaN               NaN               NaN
# streetnumber                       16218             13127             16051
# streetbuilding                       NaN               NaN               NaN
# streetpredir                         NaN               NaN               NaN
# streetname              COUNTY ROAD 1113  COUNTY ROAD 1141  COUNTY ROAD 1134
# streettype                           NaN               NaN               NaN
# streetpostdir                        NaN               NaN               NaN
# unit_type                            NaN               NaN               NaN
# unit                                 NaN               NaN               NaN
# city                               FLINT             TYLER             TYLER
# zip                                75762             75709             75709
# zip4                                 NaN               NaN               NaN
# mail1                                NaN               NaN       PO BOX 1618
# mail2                                NaN               NaN               NaN
# mail3                                NaN               NaN               NaN
# mailcity                             NaN               NaN          CHANDLER
# mailstate                            NaN               NaN                TX
# mailzip                              NaN               NaN             75758
# mailzip4                             NaN               NaN                 0
# sex                                    M                 M                 F
# birthdate                        4/29/47           12/2/73            3/7/26
# eligible_date                    5/23/99           4/23/17           7/23/94
# effective_date                    1/1/12           4/23/17            1/1/12
# ...                                  ...               ...               ...
# election_code34                      NaN               NaN               NaN
# vote_type34                          NaN               NaN               NaN
# party_code34                         NaN               NaN               NaN
# election_code35                      NaN               NaN               NaN
# vote_type35                          NaN               NaN               NaN
# party_code35                         NaN               NaN               NaN
# election_code36                      NaN               NaN               NaN
# vote_type36                          NaN               NaN               NaN
# party_code36                         NaN               NaN               NaN
# election_code37                      NaN               NaN               NaN
# vote_type37                          NaN               NaN               NaN
# party_code37                         NaN               NaN               NaN
# election_code38                      NaN               NaN               NaN
# vote_type38                          NaN               NaN               NaN
# party_code38                         NaN               NaN               NaN
# election_code39                      NaN               NaN               NaN
# vote_type39                          NaN               NaN               NaN
# party_code39                         NaN               NaN               NaN
# election_code40                      NaN               NaN               NaN
# vote_type40                          NaN               NaN               NaN
# party_code40                         NaN               NaN               NaN
# registration_date                4/23/99           3/24/17           6/23/94
# party_affiliation_date               NaN           3/24/17               NaN
# last_activity_date               3/10/15           3/28/17           9/17/18
# precinct_group                       NaN               NaN               NaN
# phone_number                         NaN               NaN               NaN
# ID_Compliant                           Y                 Y                 Y
# Absentee_Category                    NaN               NaN               Y65
# Absentee_Category_Date               NaN               NaN           9/17/18
# Ethnicity                            NaN               NaN               NaN
#
#                               89191             89192            89193  \
# SOS_VoterID             2.14893e+09       1.12906e+09      1.17761e+09
# idnumber                   80149269            146819         80073294
# voter_status                      A                 A                A
# party_code                      NaN               NaN              NaN
# lastname                    BURGESS           BURKHAM      BURKS-JONES
# firstname                    ISIAHA            MARLON           BESSIE
# middlename                   JAVONE           RANDALL              LEE
# namesuffix                      NaN               NaN              NaN
# streetnumber                  12993             15075            13652
# streetbuilding                  NaN               NaN              NaN
# streetpredir                    NaN               NaN              NaN
# streetname                   HWY 31  COUNTY ROAD 1134           MAXINE
# streettype                      NaN               NaN               DR
# streetpostdir                     W               NaN              NaN
# unit_type                       NaN               NaN              NaN
# unit                            NaN               NaN              NaN
# city                          TYLER             TYLER            TYLER
# zip                           75709             75709            75709
# zip4                            NaN               NaN              NaN
# mail1                           NaN     15075 CR 1134  13652 MAXINE DR
# mail2                           NaN               NaN              NaN
# mail3                           NaN               NaN              NaN
# mailcity                        NaN             TYLER            TYLER
# mailstate                       NaN                TX               TX
# mailzip                         NaN             75709            75709
# mailzip4                        NaN               NaN              NaN
# sex                               M                 M                F
# birthdate                   8/21/00           8/15/60           5/7/43
# eligible_date              10/27/18           9/16/07          4/29/11
# effective_date             10/27/18            1/1/12           1/1/12
# ...                             ...               ...              ...
# election_code34                 NaN               NaN              NaN
# vote_type34                     NaN               NaN              NaN
# party_code34                    NaN               NaN              NaN
# election_code35                 NaN               NaN              NaN
# vote_type35                     NaN               NaN              NaN
# party_code35                    NaN               NaN              NaN
# election_code36                 NaN               NaN              NaN
# vote_type36                     NaN               NaN              NaN
# party_code36                    NaN               NaN              NaN
# election_code37                 NaN               NaN              NaN
# vote_type37                     NaN               NaN              NaN
# party_code37                    NaN               NaN              NaN
# election_code38                 NaN               NaN              NaN
# vote_type38                     NaN               NaN              NaN
# party_code38                    NaN               NaN              NaN
# election_code39                 NaN               NaN              NaN
# vote_type39                     NaN               NaN              NaN
# party_code39                    NaN               NaN              NaN
# election_code40                 NaN               NaN              NaN
# vote_type40                     NaN               NaN              NaN
# party_code40                    NaN               NaN              NaN
# registration_date           9/27/18           8/17/07          3/30/11
# party_affiliation_date      9/27/18               NaN              NaN
# last_activity_date          9/28/18           3/10/15          8/27/14
# precinct_group                  NaN               NaN              NaN
# phone_number                    NaN               NaN              NaN
# ID_Compliant                      Y                 Y                Y
# Absentee_Category               NaN               NaN              NaN
# Absentee_Category_Date          NaN               NaN              NaN
# Ethnicity                       NaN               NaN              NaN
#
#                                   89194             89195
# SOS_VoterID                 1.12848e+09       1.12902e+09
# idnumber                         237499            150343
# voter_status                          A                 A
# party_code                          NaN               NaN
# lastname                       BURNETTE             BURNS
# firstname                        SHERRY             FAIRY
# middlename                        KOTON              WARD
# namesuffix                          NaN               NaN
# streetnumber                       7259             13065
# streetbuilding                      NaN               NaN
# streetpredir                        NaN               NaN
# streetname              PLEASANT HOLLOW  COUNTY ROAD 1141
# streettype                           RD               NaN
# streetpostdir                       NaN               NaN
# unit_type                           NaN               NaN
# unit                                NaN               NaN
# city                              TYLER             TYLER
# zip                               75709             75709
# zip4                                NaN               NaN
# mail1                               NaN     13065 CR 1141
# mail2                               NaN               NaN
# mail3                               NaN               NaN
# mailcity                            NaN             TYLER
# mailstate                           NaN                TX
# mailzip                             NaN             75709
# mailzip4                            NaN               NaN
# sex                                   F                 F
# birthdate                       5/27/65          11/13/50
# eligible_date                   11/5/00           9/23/88
# effective_date                  5/27/12            1/1/12
# ...                                 ...               ...
# election_code34                     NaN               NaN
# vote_type34                         NaN               NaN
# party_code34                        NaN               NaN
# election_code35                     NaN               NaN
# vote_type35                         NaN               NaN
# party_code35                        NaN               NaN
# election_code36                     NaN               NaN
# vote_type36                         NaN               NaN
# party_code36                        NaN               NaN
# election_code37                     NaN               NaN
# vote_type37                         NaN               NaN
# party_code37                        NaN               NaN
# election_code38                     NaN               NaN
# vote_type38                         NaN               NaN
# party_code38                        NaN               NaN
# election_code39                     NaN               NaN
# vote_type39                         NaN               NaN
# party_code39                        NaN               NaN
# election_code40                     NaN               NaN
# vote_type40                         NaN               NaN
# party_code40                        NaN               NaN
# registration_date               10/6/00           8/24/88
# party_affiliation_date              NaN               NaN
# last_activity_date              1/28/15          11/10/14
# precinct_group                      NaN               NaN
# phone_number                        NaN               NaN
# ID_Compliant                          Y                 Y
# Absentee_Category                   NaN               NaN
# Absentee_Category_Date              NaN               NaN
# Ethnicity                           NaN               NaN
#
# [211 rows x 89196 columns]

# %%
# Smooshing together all the early voting data
# This is like copying and pasting them together, quickly 
frames = [voters1, voters2, voters3]
voters2018 = pd.concat(frames, sort=False)

# %%
# Show me the top of my new dataframe
voters2018.head(5)
# Out:
#     SOS_VoterID    idnumber voter_status  party_code lastname  firstname  \
# 0  2.140230e+09  80139849.0            S         NaN    ADAMS  DOMINIQUE
# 1  1.128803e+09       287.0            A         NaN    ADAMS     WILLIE
# 2  2.140351e+09  80140000.0            A         NaN  AGUILAR      EDGAR
# 3  1.129249e+09    242762.0            A         NaN  AGUILAR      MARIA
# 4  1.182291e+09  80077967.0            A         NaN  ALARCON     JAZMIN
#
#   middlename namesuffix  streetnumber streetbuilding  ...  JP3 Unnamed: 62  \
# 0     ALEXIS        NaN        3400.0            NaN  ...  NaN         NaN
# 1        RAY        NaN        2801.0            NaN  ...  NaN         NaN
# 2       IVAN        NaN        1121.0            NaN  ...  NaN         NaN
# 3       CRUZ        NaN        1121.0            NaN  ...  NaN         NaN
# 4        NaN        NaN         269.0            NaN  ...  NaN         NaN
#
#    REP 16PR REP.1 14GE  P.1  E.2  7/30/10 8/13/12
# 0  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 1  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 2  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 3  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 4  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
#
# [5 rows x 456 columns]

# %%
# Tell me the length of my new dataframe 
# This is how many people are on the voter list Smith County 
len(voters2018)
# Out:
# 135626

# %%
voters2018.head(5)
# Out:
#     SOS_VoterID    idnumber voter_status  party_code lastname  firstname  \
# 0  2.140230e+09  80139849.0            S         NaN    ADAMS  DOMINIQUE
# 1  1.128803e+09       287.0            A         NaN    ADAMS     WILLIE
# 2  2.140351e+09  80140000.0            A         NaN  AGUILAR      EDGAR
# 3  1.129249e+09    242762.0            A         NaN  AGUILAR      MARIA
# 4  1.182291e+09  80077967.0            A         NaN  ALARCON     JAZMIN
#
#   middlename namesuffix  streetnumber streetbuilding  ...  JP3 Unnamed: 62  \
# 0     ALEXIS        NaN        3400.0            NaN  ...  NaN         NaN
# 1        RAY        NaN        2801.0            NaN  ...  NaN         NaN
# 2       IVAN        NaN        1121.0            NaN  ...  NaN         NaN
# 3       CRUZ        NaN        1121.0            NaN  ...  NaN         NaN
# 4        NaN        NaN         269.0            NaN  ...  NaN         NaN
#
#    REP 16PR REP.1 14GE  P.1  E.2  7/30/10 8/13/12
# 0  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 1  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 2  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 3  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 4  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
#
# [5 rows x 456 columns]

# %%
voters2018.head(5)
# Out:
#     SOS_VoterID    idnumber voter_status  party_code lastname  firstname  \
# 0  2.140230e+09  80139849.0            S         NaN    ADAMS  DOMINIQUE
# 1  1.128803e+09       287.0            A         NaN    ADAMS     WILLIE
# 2  2.140351e+09  80140000.0            A         NaN  AGUILAR      EDGAR
# 3  1.129249e+09    242762.0            A         NaN  AGUILAR      MARIA
# 4  1.182291e+09  80077967.0            A         NaN  ALARCON     JAZMIN
#
#   middlename namesuffix  streetnumber streetbuilding  ...  JP3 Unnamed: 62  \
# 0     ALEXIS        NaN        3400.0            NaN  ...  NaN         NaN
# 1        RAY        NaN        2801.0            NaN  ...  NaN         NaN
# 2       IVAN        NaN        1121.0            NaN  ...  NaN         NaN
# 3       CRUZ        NaN        1121.0            NaN  ...  NaN         NaN
# 4        NaN        NaN         269.0            NaN  ...  NaN         NaN
#
#    REP 16PR REP.1 14GE  P.1  E.2  7/30/10 8/13/12
# 0  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 1  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 2  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 3  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
# 4  NaN  NaN   NaN  NaN  NaN  NaN      NaN     NaN
#
# [5 rows x 456 columns]

# %%
df = pd.DataFrame(voters2018)
df.to_csv(r'SC-Voter-List-FULL-2018.csv')
